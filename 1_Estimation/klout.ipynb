# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("udacity_inferential_stats.xlsx", header=None,names={"Klout"})
data
# Out:
#           Klout
# 0     25.104179
# 1     60.908747
# 2     23.222238
# 3     51.553491
# 4     22.629690
# ...         ...
# 1043  28.544280
# 1044  16.647022
# 1045  40.078943
# 1046  51.085002
# 1047  22.430099
#
# [1048 rows x 1 columns]

# %% [markdown]
# # What is the mean of this population?

# %%
mean_pop =data.mean()
mean_pop
# Out:
# Klout    37.719055
# dtype: float64

# %% [markdown]
# # What is the population standard deviation?

# %%
pop_std = data.std()
pop_std
# Out:
# Klout    16.044315
# dtype: float64

# %% [markdown]
# # What is the mean of this distribution?
# # A. the same as the population mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is the standard error?
#
#
# # A. Divide the population standard deviation by the square root of "n". "n" is the sample size. in this example, the sample size is 35 (not 1048)

# %%
import math

# %%
data_sample_size_sqrt=math.sqrt(35)
data_sample_size_sqrt
# Out:
# 5.916079783099616

# %%
standard_error = pop_std/data_sample_size_sqrt
standard_error
# Out:
# Klout    2.711984
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sampling distribution for the population of Klout
# # We need sampling distribution becasuse we want to imcrease Klout scores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # n = sample size = 35
# # group A's Klout score = 40
# # the population mean = 37.72
# # the standard deviation = 2.71
#
# # What is z score of group A? (=what is z socre for a mean of 40?)
# # (=How many standard deviations above the mean of this distribution (distribution for the population of Klout) does this mean lie ? )
#
#
#
# # ( group A socre - the population mean) / the standard deviation

# %%
group_score=40

# %%
(group_score-mean_pop)/standard_error
# Out:
# Klout    0.841061
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is the probability of random drawing a sample of size 35 with a mean of at least 40?
#
# # A. 1. Find a z socre in (z-table)[https://s3.amazonaws.com/udacity-hosted-downloads/ZTable.jpg]
# # 2. (1- "the value from step1") = Answer.  1 is 100% of probability

# %%
1-0.7995
# Out:
# 0.2005
