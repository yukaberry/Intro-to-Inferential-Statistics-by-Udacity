# %%
import pandas as pd
import numpy as np
import math

# %%
data = pd.read_excel("udacity_inferential_stats.xlsx", header=None,names={"Klout"})
data
# Out:
#           Klout
# 0     25.104179
# 1     60.908747
# 2     23.222238
# 3     51.553491
# 4     22.629690
# ...         ...
# 1043  28.544280
# 1044  16.647022
# 1045  40.078943
# 1046  51.085002
# 1047  22.430099
#
# [1048 rows x 1 columns]

# %%
mean_pop =data.mean()
mean_pop
# Out:
# Klout    37.719055
# dtype: float64

# %%
pop_std = data.std()
pop_std
# Out:
# Klout    16.044315
# dtype: float64

# %%
data_sample_size_sqrt=math.sqrt(250)
data_sample_size_sqrt
# Out:
# 15.811388300841896

# %%
standard_error = pop_std/data_sample_size_sqrt
standard_error
# Out:
# Klout    1.014732
# dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Z-score for mean 40 from sample size 250

# %%
group_score=40

# %%
(group_score-mean_pop)/standard_error
# Out:
# Klout    2.247831
# dtype: float64

# %% [markdown]
# # Probability of randomly selecting sample (250) with mean at least 40?

# %%
1-0.9875
# Out:
# 0.012499999999999956
