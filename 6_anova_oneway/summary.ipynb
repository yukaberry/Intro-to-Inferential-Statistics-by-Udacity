# %% [markdown]
# # 5 steps for ANOVA

# %% [markdown]
# # 1.
#
# Ho = M1 =M2 = m3
#
# Ha = at least 1 differ from the others
# a = 0.05
#
# * sample 1 = {1,2,5}
# * sample 2 = {2,4,2}
# * sample 1 = {2,3,4}
#
#
#
# # 2. Calculate Degree of freedom to get F critical value
#
# * Degree of freedom between = k - 1 = 3 -1 = 2
#     - **K is the number of population group.** in this example, 3
#
# * Degree of freedom within = N -k = 9 -3 = 6
#     - **N is total number of scores that we in our sample**
#
# * Degree of difference total = Degree of freedowm between + degree of freedom within = 6+2 = 8
#
# * F critical value = 5.14
#     - **Find a value below the table or online calculater [here](https://www.danielsoper.com/statcalc/calculator.aspx?id=4)**
#     - degree of freedom numerator = colums in excel sheet = degree of freedom 1  in Critical F-value Calculator
#     - degree of freefom denominator = row in excel sheet = degree of freedom 2 in Critical F-value Calculator
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Analysis of the sum of the squares or the sum of squared deviations
#
#
# * x_1(sample1) = 2.67 = (1+2+5)/3
# * x_2(sample2) = 2.67 = (2+4+2)/3
# * x_3(sample3) = 3.00 = (2+3+4)/3
# * G/N(grand mean) =grand total/n = 25/9 = 2.78
#
# * sum of the squares total = sum(x-G/N)
#     - (1-2.78)2 + (2-2.78)2 + (5-2.78)2 +(2-2.78)2 + (4-2.78)2 + (2-2.78)2+  (2-2.78)2 + (3-2.78)2 + (4-2.78)2 = 13.6
#
# * sum of the squares within = sum (x1 -x_1)2 + (x2 - x_2)2 +(x3 - x_3)2
#     - (1-2.67)2 +(2-2.67)2 + (5-2.67) +  (2-2.67)2 +(4-2.67)2 + (2-2.67) +  (2-3)2 +(3-3)2 + (4-3)2 = 13.34
#
# * sum of the squares between =  sum of the squares total -  sum of the squares within
#     - 13.6 - 13.3 = 0.23

# %% [markdown]
# # 4 calculate the variance between and the variance within
#
# * the variance mean square between = sum of the squares between / degrees of freedom between
#     - 0.23 / 2 = 0.12
#
# * the variance within = mean square within /degrees of freedom within
#     - 13.34/6 = 2.22

# %% [markdown]
# # 5. Calculate F statistic
#
# * F = mean squre between/mean squre within
#     - 0.12/2.22 = 0.05
#
# * F critical 5.14
#
# * 0.05 < 5.14
# # Result:
# # Fail to reject Ho(hypothesis). Ho: M1=M2=M3(there is no significant difference between 3 groups). Since we failed to reject that, we conclude there is no significant difference between the 3 groups.
